# %%
import sentencepiece as spm

# %%
sp = spm.SentencePieceProcessor()
sp.load("/export/fs05/mkhelfi1/hyperionnew/hyperion-adc24/egs/adc24/V2/data/qasr/ar_lang_bpe_200/bpe.model")
sp2 = spm.SentencePieceProcessor()
sp2.load("/export/fs05/mkhelfi1/hyperionnew/hyperion-adc24/egs/adc24/V2/data/qasr/ar_lang_bpe_5000/unigram_5000.model")


sentence = "هذا نص عربي طويل يحتوي على العديد من الكلمات والجمل لاختبار قدرة النظام على التعامل مع النصوص الكبيرة. الهدف من هذا الاختبار هو التأكد من أن عملية التقطيع والتحليل تعمل بشكل صحيح وفعّال. كما يهدف إلى قياس مدى دقة النظام في معالجة النصوص المكتوبة باللغة العربية بدون تشكيل أو علامات إضافية. النص يشمل عدة موضوعات وأفكار متتالية للتأكد من كفاءة النظام في فهم السياق وإعادة بناء النصوص بعد معالجتها."
token_pieces = sp.encode(sentence, out_type=str)
print("Encoded (subword units):", token_pieces)



token_pieces = sp2.encode(sentence, out_type=str)
print("Encoded (subword units):", token_pieces)
# Out:
# Encoded (subword units): ['▁هذا', '▁ن', 'ص', '▁ع', 'ر', 'ب', 'ي', '▁', 'ط', 'و', 'ي', 'ل', '▁ي', 'ح', 'ت', 'و', 'ي', '▁ع', 'ل', 'ى', '▁الع', 'دي', 'د', '▁من', '▁ال', 'ك', 'ل', 'م', 'ات', '▁وال', 'ج', 'م', 'ل', '▁لا', 'خ', 'ت', 'ب', 'ار', '▁ق', 'د', 'ر', 'ة', '▁ال', 'ن', 'ظ', 'ام', '▁ع', 'ل', 'ى', '▁الت', 'ع', 'ام', 'ل', '▁مع', '▁ال', 'ن', 'ص', 'و', 'ص', '▁ال', 'ك', 'ب', 'ي', 'ر', 'ة', '.', '▁ال', 'ه', 'د', 'ف', '▁من', '▁هذا', '▁الا', 'خ', 'ت', 'ب', 'ار', '▁', 'ه', 'و', '▁الت', 'أ', 'ك', 'د', '▁من', '▁', 'أ', 'ن', '▁ع', 'م', 'ل', 'ي', 'ة', '▁الت', 'ق', 'ط', 'ي', 'ع', '▁وال', 'ت', 'ح', 'ل', 'ي', 'ل', '▁ت', 'ع', 'م', 'ل', '▁ب', 'ش', 'ك', 'ل', '▁', 'ص', 'ح', 'ي', 'ح', '▁و', 'ف', 'ع', 'ّ', 'ال', '.', '▁ك', 'ما', '▁ي', 'ه', 'د', 'ف', '▁', 'إ', 'ل', 'ى', '▁ق', 'ي', 'ا', 'س', '▁م', 'د', 'ى', '▁', 'د', 'ق', 'ة', '▁ال', 'ن', 'ظ', 'ام', '▁في', '▁مع', 'ال', 'ج', 'ة', '▁ال', 'ن', 'ص', 'و', 'ص', '▁الم', 'ك', 'ت', 'و', 'ب', 'ة', '▁بال', 'ل', 'غ', 'ة', '▁الع', 'ر', 'ب', 'ي', 'ة', '▁ب', 'د', 'ون', '▁
# ...
